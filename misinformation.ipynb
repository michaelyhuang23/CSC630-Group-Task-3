# %%
import nltk
from collections import Counter
from nltk.corpus import stopwords

st_words = set(stopwords.words('english'))
st_words = st_words.union(set(['would', 'said', 'one', 'like', 'new',
                'also', 'even', 'get', 'could', 'time',
                'going', 'many', 'via', 'make', 'gets', 
                'says', 'know', 'image', 'told', 'made',
                'two', 'think', 'first', 'last', 'may', 
                'back', 'political']))

print(st_words)
# Out:
# {'image', 'been', 'a', 'because', 'will', 'myself', 'both', 'y', 'at', 'out', "didn't", 'some', 'our', 'shan', 'to', 'had', 'until', "it's", 'when', 'don', 'mightn', 'could', 'with', 'other', "you're", 'she', 'while', 'here', "you'll", 'same', 'ma', 'my', 'than', 'one', 'those', 'yourselves', 'going', 'not', 'm', 'on', 'then', 'll', 'made', 'just', 'ours', 'also', "you'd", 'as', "needn't", 'we', 'how', 'does', 'o', 'there', 'up', 'most', 'wouldn', "you've", 'but', 'first', 'so', 'make', 'hers', 'yours', 'know', "shan't", 'him', 'yourself', 'think', 'herself', 'do', 'few', 'is', 'all', "weren't", 'after', 'told', 'which', 'via', 'or', 'where', 'couldn', 'are', 'time', 'says', 'and', 'of', 'i', 'would', 'last', 'that', 'has', 'once', 've', 'down', 'doing', 'through', 'did', 'its', 'back', 'have', 'an', 'below', 'each', 'he', 'isn', 'again', 'too', 'gets', 'about', 'what', 'her', 'am', 'it', "won't", 'such', 'shouldn', 'won', 'political', 'into', 'ain', 'from', 'by', 'were', 'why', "isn't", "wasn't", 'many', 'being', 'over', "couldn't", "aren't", 'like', 'be', 'off', 'further', 'if', "hasn't", 'mustn', 'should', "doesn't", 'haven', 'get', 'now', 'them', 'new', 'me', 'no', 'whom', 'didn', 'theirs', 'hadn', 'hasn', 'can', 'their', 'above', "should've", 'may', 'only', 'weren', 'itself', "don't", 'ourselves', 'between', 'who', "shouldn't", 'your', 'more', 'two', 'any', 're', "hadn't", 'in', 'before', 'himself', 'for', 'needn', 'wasn', 'against', 'nor', 'was', 'this', 'his', 'own', 'even', 'having', 'aren', "that'll", 'said', "she's", 'during', 'they', 's', "haven't", 't', 'themselves', 'these', 'doesn', "mustn't", 'under', 'very', 'you', 'the', "wouldn't", 'd', "mightn't"}

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import altair as alt
import numpy as np
import pandas as pd
import datetime


def cond(word):
    if not (not word.isalnum() or 'donald' in word or word in st_words):
        return True
    else:
        return False

data = pd.read_csv("Fake Email.csv")
cc = Counter()
ndates = []
cdates = []
for i, row in data.iterrows():
    txt = row['text'].lower().split()
    date = row['date']
    try:
        ndates.append(date.split(', ')[1]+" "+date.split(' ')[0])
    except:
        ndates.append('2015 Jan')
        continue
        
    txt = [xt for xt in txt if cond(xt)]
    for word in txt:
        cc[word]+=1
        
cdates = ndates.copy()

for i in range(len(ndates)):
    ndates[i] = ndates[i].replace('December', 'Dec')
    ndates[i] = ndates[i].replace('August', 'Aug')
    ndates[i] = ndates[i].replace('February', 'Feb')
    ndates[i] = ndates[i].replace('January', 'Jan')
    ndates[i] = ndates[i].replace('October', 'Oct')
    ndates[i] = ndates[i].replace('June', 'Jun')
    ndates[i] = ndates[i].replace('July', 'Jul')
    ndates[i] = ndates[i].replace('September', 'Sep')
    ndates[i] = ndates[i].replace('March', 'Mar')
    ndates[i] = ndates[i].replace('April', 'Apr')
    ndates[i] = ndates[i].replace('November', 'Nov')
    
    cdates[i] = ndates[i].replace('Dec', '12')
    cdates[i] = cdates[i].replace('Nov', '11')
    cdates[i] = cdates[i].replace('Oct', '10')
    cdates[i] = cdates[i].replace('Sep', '9')
    cdates[i] = cdates[i].replace('Aug', '8')
    cdates[i] = cdates[i].replace('Jul', '7')
    cdates[i] = cdates[i].replace('Jun', '6')
    cdates[i] = cdates[i].replace('May', '5')
    cdates[i] = cdates[i].replace('Apr', '4')
    cdates[i] = cdates[i].replace('Mar', '3')
    cdates[i] = cdates[i].replace('Feb', '2')
    cdates[i] = cdates[i].replace('Jan', '1')
    #print(cdates[i], ndates[i])
    cdates[i] = datetime.datetime.strptime(cdates[i], "%Y %m").date()


data['date']=cdates


front = cc.most_common()[:20]
print(cc.most_common()[:20])
front = [fr[0] for fr in front]

data=data.sort_values('date')
cdates = data['date']
fdates = []
for date in cdates:
    if len(fdates)==0 or fdates[-1]!=date:
        fdates.append(date)

print(data.head())

counter = {}
for i, row in data.iterrows():
    c = Counter()
    txt= row['text'].lower().split()
    date = str(row['date'])
    txt = [xt for xt in txt if cond(xt)]
    for word in txt:
        if word in front:
            c[word]+=1
    if not date in counter: counter[date] = Counter()
    counter[date].update(c)

src = []
for date in fdates:
    c = counter[str(date)]
    for k, v in c.items():
        src.append((str(date)[:-3], k, v))

df = pd.DataFrame(src, columns=['date','word','count'])

# colors = ['red', 'orange', 'blue']
# cols = []
# for i, row in df.iterrows():
# 	cols.append(colors[front.index(row['word'])])

# df['col'] = cols
df = df[['date','word','count']]


print(df)
# Out:
# [('trump', 65447), ('people', 22330), ('president', 22047), ('obama', 16036), ('clinton', 15606), ('hillary', 12573), ('white', 12213), ('news', 12095), ('us', 11806), ('state', 10817), ('american', 9552), ('media', 9289), ('republican', 8528), ('house', 8514), ('campaign', 8330), ('united', 7860), ('police', 7773), ('america', 7745), ('government', 7244), ('black', 7054)]
#                                                    title  \
# 15840  https://fedup.wpengine.com/wp-content/uploads/...
# 9073   WATCH SHERIFF’S Honest Response After a School...
# 15507  https://100percentfedup.com/video-hillary-aske...
# 9075   POLITICS FIRST: LEFTIST PARENTS Of Former Comb...
# 9076   TWO HIGH SCHOOL JROTC Members Tell INCREDIBLE ...
#
#                                                     text   subject        date
# 15840  https://fedup.wpengine.com/wp-content/uploads/...  politics  2015-01-01
# 9073   When it gets down to it, what this sheriff sai...  politics  2015-01-01
# 15507  https://100percentfedup.com/video-hillary-aske...  politics  2015-01-01
# 9075   The heartbreaking story of two parents who put...  politics  2015-01-01
# 9076   ABC News  When two Marjory Stoneman Douglas Hi...  politics  2015-01-01
#         date        word  count
# 0    2015-01      people     29
# 1    2015-01          us      5
# 2    2015-01       state     16
# 3    2015-01    campaign     22
# 4    2015-01   president     33
# ..       ...         ...    ...
# 688  2017-12      united    277
# 689  2017-12     america    197
# 690  2017-12        news    544
# 691  2017-12  republican    146
# 692  2017-12    campaign    208
#
# [693 rows x 3 columns]

# %%
alt.Chart(df).mark_line().encode(
    x='date',
    y='count',
    color=alt.Color('word',sort=alt.EncodingSortField('count', op='mean', order='descending')),
    tooltip=['word', 'count']
).properties(title={
      "text": ["the usage frequency of the 20 most frequently used words in news articles"]})
# Out:
# alt.Chart(...)

# %%
import nltk
from collections import Counter
from nltk.corpus import stopwords

st_words = set(stopwords.words('english'))
st_words = st_words.union(set(['would', 'said', 'one', 'like', 'new',
                'also', 'even', 'get', 'could', 'time',
                'going', 'many', 'via', 'make', 'gets', 
                'says', 'know', 'image', 'told', 'made',
                'two', 'think', 'first', 'last', 'may', 
                'back', 'political']))

print(st_words)
# Out:
# {"don't", "didn't", "haven't", 'myself', 'these', 'had', 'haven', 'if', 'him', 'i', 'more', 'themselves', 'down', 're', 'very', 'after', 'ma', 'don', 'each', 'back', 'my', 'doing', 'while', 'from', 's', 'does', 'where', "wasn't", 'been', 'do', 'be', 'who', 'below', 'first', "needn't", 'them', "mightn't", 'also', 'himself', 'were', 'there', 't', 'which', "hasn't", 'made', 'is', 'what', 'as', "won't", 'most', 'was', "couldn't", 'out', 'did', 'o', "shouldn't", "hadn't", 'yourselves', 'into', 'its', 'just', 'new', 'about', 'two', 'than', 'same', 'so', "isn't", 'have', 'whom', 'off', 'ourselves', 'ain', 'once', 'such', 'should', 'needn', 'by', 'under', "that'll", 'or', 'last', 'shan', 'now', 'won', 'mustn', 'wouldn', 'gets', 'he', 'itself', 'through', 'in', 'no', 'only', 'before', 'having', 'me', 'we', "you've", 'why', 'nor', 'yours', 'his', 'mightn', 'time', 'own', "shan't", 'ours', 've', 'going', 'even', 'yourself', 'again', 'hasn', 'can', 'their', "she's", 'the', 'of', 'like', 'few', 'up', 'y', 'some', 'one', 'has', 'during', "should've", 'says', 'other', 'here', 'those', "aren't", "it's", 'all', 'above', 'political', 'how', 'hers', 'that', 'any', "doesn't", 'then', 'her', 'because', 'couldn', 'hadn', 'for', 'are', "weren't", 'many', 'know', 'at', 'image', "you're", 'both', 'isn', 'to', 'doesn', 'further', "you'd", 'until', 'but', 'theirs', 'get', 'it', 'a', 'wasn', "mustn't", 'too', "you'll", 'this', 'shouldn', 'weren', 'may', 'against', 'our', 'you', 'they', 'm', "wouldn't", 'an', 'your', 'via', 'think', 'said', 'she', 'being', 'between', 'told', 'and', 'will', 'could', 'aren', 'over', 'll', 'didn', 'am', 'make', 'when', 'herself', 'with', 'on', 'd', 'would', 'not'}

# %%
import pandas as pd
emails = pd.read_csv("Fake Email.csv")
cctit = Counter()
cctxt = Counter()
for i, row in emails.iterrows():
    tit = row['title'].lower()
    txt = row['text'].lower()
    tit = tit.split()
    txt = txt.split()
    tit = [it for it in tit if not it in st_words]
    tit = [it for it in tit if not (not it.isalnum() or 'donald' in it)]
    txt = [xt for xt in txt if not xt in st_words]
    txt = [xt for xt in txt if not (not xt.isalnum() or 'donald' in xt)]
    ctit = Counter(tit)
    ctxt = Counter(txt)
    cctit.update(ctit)
    cctxt.update(ctxt)

# %%
print(cctit.most_common()[:20])
print()
print(cctxt.most_common()[:20])
# Out:
# [('trump', 6615), ('obama', 1645), ('hillary', 1591), ('president', 971), ('clinton', 882), ('black', 806), ('gop', 736), ('white', 736), ('watch', 653), ('muslim', 612), ('news', 588), ('media', 572), ('us', 529), ('video', 511), ('bill', 509), ('house', 495), ('fox', 433), ('campaign', 422), ('people', 416), ('cnn', 410)]
#
# [('trump', 65511), ('people', 22359), ('president', 22080), ('obama', 16043), ('clinton', 15614), ('hillary', 12584), ('white', 12235), ('news', 12123), ('us', 11811), ('state', 10833), ('american', 9566), ('media', 9323), ('republican', 8538), ('house', 8525), ('campaign', 8352), ('united', 7878), ('police', 7780), ('america', 7751), ('government', 7247), ('black', 7063)]
